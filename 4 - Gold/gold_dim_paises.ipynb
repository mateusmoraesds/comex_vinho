# %% [markdown]
# ## Gold: Dimensão Países

# %%
# %run "../1 - Setup/Ingestao_bibliotecas_padrao"

# %%
from pyspark.sql.functions import col
from pyspark.sql import SparkSession
from pyspark.sql.types import StructType, StructField, StringType

# %%
schema_paises = StructType([
    StructField("iso_code", StringType(), False),  
    StructField("nome_ingles", StringType(), False),
    StructField("nome_portugues", StringType(), False)
])

# 3. Dados dos Países (ISO, Nome em Inglês, Nome em Português)
# Esta lista foi construída a partir do cruzamento dos seus dois arquivos CSV.
dados_paises = [
    ('AF', 'Afghanistan', 'Afeganistão'),
    ('ZA', 'South Africa', 'África do Sul'),
    ('DE', 'Germany', 'Alemanha'),
    ('AO', 'Angola', 'Angola'),
    ('AI', 'Anguilla', 'Anguilla'),
    ('AG', 'Antigua and Barbuda', 'Antígua e Barbuda'),
    ('SA', 'Saudi Arabia', 'Arábia Saudita'),
    ('AR', 'Argentina', 'Argentina'),
    ('AW', 'Aruba', 'Aruba'),
    ('AU', 'Australia', 'Austrália'),
    ('AT', 'Austria', 'Áustria'),
    ('BS', 'Bahamas, The', 'Bahamas'),
    ('BD', 'Bangladesh', 'Bangladesh'),
    ('BB', 'Barbados', 'Barbados'),
    ('BH', 'Bahrain', 'Barein'),
    ('BE', 'Belgium', 'Bélgica'),
    ('BZ', 'Belize', 'Belice'),
    ('BJ', 'Benin', 'Benin'),
    ('BM', 'Bermuda', 'Bermudas'),
    ('BO', 'Bolivia', 'Bolívia'),
    ('BA', 'Bosnia and Herzegovina', 'Bósnia-Herzegovina'),
    ('BR', 'Brazil', 'Brasil'),
    ('BG', 'Bulgaria', 'Bulgária'),
    ('CV', 'Cabo Verde', 'Cabo Verde'),
    ('CM', 'Cameroon', 'Camarões'),
    ('CA', 'Canada', 'Canadá'),
    ('QA', 'Qatar', 'Catar'),
    ('KY', 'Cayman Islands', 'Cayman'), # Ilhas Cayman
    ('CL', 'Chile', 'Chile'),
    ('CN', 'China', 'China'),
    ('CY', 'Cyprus', 'Chipre'),
    ('SG', 'Singapore', 'Cingapura'),
    ('CC', 'Cocos (Keeling) Islands', 'Cocos (Keeling)'), # Ilhas Cocos (Keeling)
    ('CO', 'Colombia', 'Colômbia'),
    ('KM', 'Comoros', 'Comores'),
    ('CG', 'Congo, Rep.', 'Congo'),
    ('KR', 'Korea, Rep.', 'Coreia'),
    ('CI', 'Cote d\'Ivoire', 'Costa do Marfim'),
    ('CR', 'Costa Rica', 'Costa Rica'),
    ('HR', 'Croatia', 'Croácia'),
    ('CU', 'Cuba', 'Cuba'),
    ('CW', 'Curaçao', 'Curaçao'),
    ('DK', 'Denmark', 'Dinamarca'),
    ('DM', 'Dominica', 'Dominica'),
    ('SV', 'El Salvador', 'El Salvador'),
    ('AE', 'United Arab Emirates', 'Emirados Arabes Unidos'),
    ('EC', 'Ecuador', 'Equador'),
    ('SK', 'Slovak Republic', 'Eslovaca'), # Eslováquia
    ('ES', 'Spain', 'Espanha'),
    ('US', 'United States', 'Estados Unidos'),
    ('EE', 'Estonia', 'Estônia'),
    ('PH', 'Philippines', 'Filipinas'),
    ('FI', 'Finland', 'Finlândia'),
    ('FR', 'France', 'França'),
    ('GF', 'French Guiana', 'Guiana Francesa'),
    ('GH', 'Ghana', 'Gana'),
    ('GI', 'Gibraltar', 'Gibraltar'),
    ('GD', 'Grenada', 'Granada'),
    ('GR', 'Greece', 'Grécia'),
    ('GT', 'Guatemala', 'Guatemala'),
    ('GY', 'Guyana', 'Guiana'),
    ('GW', 'Guinea-Bissau', 'Guine Bissau'),
    ('GQ', 'Equatorial Guinea', 'Guine Equatorial'),
    ('HT', 'Haiti', 'Haiti'),
    ('HN', 'Honduras', 'Honduras'),
    ('HK', 'Hong Kong SAR, China', 'Hong Kong'),
    ('HU', 'Hungary', 'Hungria'),
    ('IM', 'Isle of Man', 'Ilha de Man'),
    ('VG', 'British Virgin Islands', 'Ilhas Virgens'), # Assumindo BVI, pois "Ilhas Virgens" é genérico
    ('IN', 'India', 'India'),
    ('ID', 'Indonesia', 'Indonésia'),
    ('IR', 'Iran, Islamic Rep.', 'Irã'),
    ('IQ', 'Iraq', 'Iraque'),
    ('IE', 'Ireland', 'Irlanda'),
    ('IT', 'Italy', 'Itália'),
    ('JM', 'Jamaica', 'Jamaica'),
    ('JP', 'Japan', 'Japão'),
    ('JO', 'Jordan', 'Jordânia'),
    ('LV', 'Latvia', 'Letônia'),
    ('LB', 'Lebanon', 'Líbano'),
    ('LR', 'Liberia', 'Libéria'),
    ('LU', 'Luxembourg', 'Luxemburgo'),
    ('MO', 'Macao SAR, China', 'Macau'),
    ('MY', 'Malaysia', 'Malásia'),
    ('MW', 'Malawi', 'Malavi'),
    ('MT', 'Malta', 'Malta'),
    ('MH', 'Marshall Islands', 'Marshall'),
    ('MQ', 'Martinique', 'Martinica'),
    ('MR', 'Mauritania', 'Mauritânia'),
    ('MX', 'Mexico', 'México'),
    ('MZ', 'Mozambique', 'Moçambique'),
    ('ME', 'Montenegro', 'Montenegro'),
    ('NA', 'Namibia', 'Namíbia'),
    ('NI', 'Nicaragua', 'Nicarágua'),
    ('NG', 'Nigeria', 'Nigéria'),
    ('NO', 'Norway', 'Noruega'),
    ('NC', 'New Caledonia', 'Nova Caledônia'),
    ('NZ', 'New Zealand', 'Nova Zelândia'),
    ('OM', 'Oman', 'Omã'),
    ('NL', 'Netherlands', 'Países Baixos'),
    ('PW', 'Palau', 'Palau'),
    ('PA', 'Panama', 'Panamá'),
    ('PY', 'Paraguay', 'Paraguai'),
    ('PE', 'Peru', 'Peru'),
    ('PL', 'Poland', 'Polônia'),
    ('PT', 'Portugal', 'Portugal'),
    ('KE', 'Kenya', 'Quênia'),
    ('GB', 'United Kingdom', 'Reino Unido'),
    ('DO', 'Dominican Republic', 'República Dominicana'),
    ('RU', 'Russian Federation', 'Rússia'),
    ('KN', 'St. Kitts and Nevis', 'São Cristóvão e Névis'),
    ('ST', 'Sao Tome and Principe', 'São Tomé e Príncipe'),
    ('VC', 'St. Vincent and the Grenadines', 'São Vicente e Granadinas'),
    ('SN', 'Senegal', 'Senegal'),
    ('SL', 'Sierra Leone', 'Serra Leoa'),
    ('SZ', 'Eswatini', 'Suazilândia'),
    ('SE', 'Sweden', 'Suécia'),
    ('CH', 'Switzerland', 'Suíça'),
    ('SR', 'Suriname', 'Suriname'),
    ('TH', 'Thailand', 'Tailândia'),
    ('TZ', 'Tanzania', 'Tanzânia'),
    ('CZ', 'Czechia', 'Tcheca'),
    ('TG', 'Togo', 'Togo'),
    ('TT', 'Trinidad and Tobago', 'Trinidade Tobago'),
    ('TN', 'Tunisia', 'Tunísia'),
    ('TR', 'Turkiye', 'Turquia'),
    ('UY', 'Uruguay', 'Uruguai'),
    ('VE', 'Venezuela, RB', 'Venezuela'),
    ('VN', 'Viet Nam', 'Vietnã')
]

# 4. Cria o DataFrame Spark
df_dim_pais = spark.createDataFrame(data=dados_paises, schema=schema_paises)

# 5. Exibe o resultado para verificação
print("Schema do DataFrame:")
df_dim_pais.printSchema()

# %%
display(df_dim_pais)

# %%
df_dim_pais.createOrReplaceTempView("paises")
df = spark.sql("""
    SELECT ROW_NUMBER() OVER (ORDER BY iso_code ASC) AS ID_PAIS,
    ISO_CODE,
    NOME_INGLES,
    NOME_PORTUGUES
    FROM paises
""")
df.createOrReplaceTempView("paises")

# %%
 #Cria tabela gerenciada no Unity Catalog
spark.sql("""
CREATE TABLE IF NOT EXISTS vitivinicultura.gold_cadastros.paises
USING DELTA
""")
# Escrita no formato Delta Lake
df.write \
    .format("delta") \
    .mode("overwrite") \
    .option("overwriteSchema", "true") \
    .saveAsTable("vitivinicultura.gold_cadastros.paises")
